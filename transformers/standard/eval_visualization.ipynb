# %% [markdown]
# ## Setup google drive and change to working directory

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# %cd "/content/drive/My Drive/github_cs230_project_mri/project_fmri/transformers/standard"
# !ls  #check to see folder contents
# Out:
# /content/drive/My Drive/github_cs230_project_mri/project_fmri/transformers/standard
# dataset.py  main_colab.ipynb  __pycache__     utils.py		   wandb
# eval.py     main.py	      transformer.py  visualization.ipynb

# %% [markdown]
# ## Load Transformer and VQVAE with Checkpoints and Eval

# %%
# !python eval.py
# Out:
# Loaded MRI data from ../../data/val/val_data.npy with 386 slices
# Saving eval visualizations to: /content/drive/MyDrive/github_cs230_project_mri/project_fmri/results/eval/20251127_211120
# [Eval] Batch 0 - mean MSE: 3.046889e-08
# Saved example visualization for slice 0 to /content/drive/MyDrive/github_cs230_project_mri/project_fmri/results/eval/20251127_211120/val_01.png
# [Eval] Batch 1 - mean MSE: 9.639775e-06
# [Eval] Batch 2 - mean MSE: 2.066166e-05
# [Eval] Batch 3 - mean MSE: 3.694693e-05
# [Eval] Batch 4 - mean MSE: 5.953062e-05
# [Eval] Batch 5 - mean MSE: 6.941265e-05
# [Eval] Batch 6 - mean MSE: 9.476249e-05
# [Eval] Batch 7 - mean MSE: 1.353226e-04
# [Eval] Batch 8 - mean MSE: 1.281199e-04
# [Eval] Batch 9 - mean MSE: 1.543812e-04
# [Eval] Batch 10 - mean MSE: 1.757474e-04
# [Eval] Batch 11 - mean MSE: 2.211959e-04
# [Eval] Batch 12 - mean MSE: 2.340000e-04
# [Eval] Batch 13 - mean MSE: 2.506606e-04
# [Eval] Batch 14 - mean MSE: 2.710856e-04
# ...
