# %% [markdown]
# # Transformers Training

# %% [markdown]
# ## Setup google drive and change to working directory

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd "/content/drive/My Drive/github_cs230_project_mri/project_fmri/transformers/standard"
# !ls  #check you see folder contents main.py etc.
# Out:
# /content/drive/My Drive/github_cs230_project_mri/project_fmri/transformers/standard
# dataset.py	  main.py      transformer.py  wandb
# main_colab.ipynb  __pycache__  utils.py

# %% [markdown]
# ## Login to wandb for logging

# %%
# !wandb login --relogin
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin

# %% [markdown]
# ## Start Training Transformers model

# %%
# !python main.py --epochs 50 --batch_size 32 --pos_encoding 1d
# Out:
# wandb: Currently logged in as: nuttay to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run 08se85ci (0.2s)
# wandb: ⣾ setting up run 08se85ci (0.2s)
# wandb: ⣷ setting up run 08se85ci (0.2s)
# wandb: Tracking run with wandb version 0.23.0
# wandb: Run data is saved locally in /content/drive/MyDrive/github_cs230_project_mri/project_fmri/transformers/standard/wandb/run-20251127_171710-08se85ci
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run transformer_encoding_1d_epochs50_lr0.0001
# wandb: ⭐️ View project at https://wandb.ai/nuttay/mri-transformer
# wandb: 🚀 View run at https://wandb.ai/nuttay/mri-transformer/runs/08se85ci
# [Epoch 1 Step 1] train_loss_step: 104.8753
# [Epoch 1 Step 10] train_loss_step: 14.9452
# [Epoch 1 Step 20] train_loss_step: 8.4097
# [Epoch 1 Step 30] train_loss_step: 11.5931
# ...

# %% [markdown]
# ## other
